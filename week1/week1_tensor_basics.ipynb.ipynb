# %%
import torch

# %%
import torch
print (torch.__version__)
print (torch.cuda.is_available())
x = torch.rand(3, 4)
print(x)
print(x.shape,x.dtype)
#如何判断GPU:!ls /dev/nvidia*
# Out:
# 2.8.0+cu128
# False
# tensor([[0.8141, 0.6394, 0.7810, 0.8015],
#         [0.8653, 0.8255, 0.7600, 0.0519],
#         [0.5092, 0.2774, 0.1450, 0.0933]])
# torch.Size([3, 4]) torch.float32
